# %%
import pandas as pd

# %%
df=pd.read_csv("student_habits_performance.csv")
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
import numpy as np

# %%
df['parental_education_level']=df['parental_education_level'].fillna(df['parental_education_level'].mode())

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df['parental_education_level'].replace('', np.nan, inplace=True)
# Out:
# C:\Users\Abhay\AppData\Local\Temp\ipykernel_12600\3736554717.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['parental_education_level'].replace('', np.nan, inplace=True)

# %%
df['parental_education_level'] = df['parental_education_level'].fillna(df['parental_education_level'].mode()[0])

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
# %pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df['study_hours_per_day'].value_counts()
# Out:
# study_hours_per_day
# 3.5    38
# 3.2    36
# 4.3    35
# 3.3    34
# 3.8    31
#        ..
# 7.5     1
# 8.2     1
# 7.6     1
# 0.1     1
# 7.1     1
# Name: count, Length: 78, dtype: int64

# %%
df['study_hours_per_day'].mode()
# Out:
# 0    3.5
# Name: study_hours_per_day, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   object
# ...

# %%
df.groupby('study_hours_per_day')['exam_score'].mean()
# Out:
# study_hours_per_day
# 0.0     40.807692
# 0.1     53.400000
# 0.2     31.500000
# 0.3     32.625000
# 0.5     39.525000
#           ...
# 7.4     99.233333
# 7.5    100.000000
# 7.6    100.000000
# 8.2    100.000000
# 8.3    100.000000
# Name: exam_score, Length: 78, dtype: float64

# %%
study = df.select_dtypes(include=["number"])
study
# Out:
#      age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0     23                  0.0                 1.2            1.1
# 1     20                  6.9                 2.8            2.3
# 2     21                  1.4                 3.1            1.3
# 3     23                  1.0                 3.9            1.0
# 4     19                  5.0                 4.4            0.5
# ..   ...                  ...                 ...            ...
# 995   21                  2.6                 0.5            1.6
# 996   17                  2.9                 1.0            2.4
# 997   20                  3.0                 2.6            1.3
# 998   24                  5.4                 4.1            1.1
# 999   19                  4.3                 2.9            1.9
#
#      attendance_percentage  sleep_hours  exercise_frequency  \
# 0                     85.0          8.0                   6
# 1                     97.3          4.6                   6
# ...

# %%
df.groupby('attendance_percentage')['exam_score'].mean()
# Out:
# attendance_percentage
# 56.0     64.500000
# 56.7     83.600000
# 57.6     75.700000
# 59.5     64.200000
# 59.7     51.500000
#            ...
# 99.1     65.500000
# 99.4     85.700000
# 99.5     84.700000
# 99.8     62.000000
# 100.0    75.572727
# Name: exam_score, Length: 320, dtype: float64

# %%
study.corr()
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.003971           -0.009151
# study_hours_per_day    0.003971             1.000000            0.020282
# social_media_hours    -0.009151             0.020282            1.000000
# netflix_hours         -0.001174            -0.031158            0.011477
# attendance_percentage -0.026055             0.026264            0.040479
# sleep_hours            0.037482            -0.027757            0.018236
# exercise_frequency    -0.003836            -0.028701           -0.037319
# mental_health_rating  -0.045101            -0.003768            0.001496
# exam_score            -0.008907             0.825419           -0.166733
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                        -0.001174              -0.026055     0.037482
# study_hours_per_day        -0.031158               0.026264    -0.027757
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(study.corr(),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='study_hours_per_day', y='exam_score', hue='gender', palette='coolwarm')
plt.title('Study Hours vs Exam Score (Colored by Gender)', fontsize=14)
plt.xlabel('Study Hours per Day')
plt.ylabel('Exam Score')
plt.legend(title='Gender')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='gender', y='exam_score', palette='pastel')
plt.title('Average Exam Score by Gender')
plt.ylabel('Average Exam Score')
plt.xlabel('Gender')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Abhay\AppData\Local\Temp\ipykernel_12600\808196116.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='gender', y='exam_score', palette='pastel')

# %%
bins = [0, 1, 3, 5, 10]
labels = ['0-1 hrs', '1-3 hrs', '3-5 hrs', '5+ hrs']
df['sm_usage_group'] = pd.cut(df['social_media_hours'], bins=bins, labels=labels)

sm_counts = df['sm_usage_group'].value_counts().sort_index()

plt.figure(figsize=(7,7))
plt.pie(sm_counts, labels=sm_counts.index, autopct='%1.1f%%', colors=sns.color_palette('Set2'))
plt.title('Social Media Usage Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['sleep_hours'], bins=8, kde=True, color='skyblue')
plt.title('Distribution of Sleep Hours')
plt.xlabel('Sleep Hours per Day')
plt.ylabel('Number of Students')
plt.tight_layout()
plt.show()

# %%
import missingno as mso

# %%
mso.matrix(df)
# Out:
# <Axes: >
